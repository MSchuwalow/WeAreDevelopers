# %%
import matplotlib
matplotlib.use('Agg')
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import imread, imresize
from os.path import join
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Activation, Flatten, Input
from keras import backend as K
from vis.visualization import visualize_cam, visualize_saliency, visualize_activation
from vis.utils import utils
from vis.losses import ActivationMaximization
from vis.regularizers import TotalVariation, LPNorm
from vis.optimizer import Optimizer
from vis.callbacks import GifGenerator
from vis.utils.vggnet import VGG16
import json
import vis.utils
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import preprocess_input

DATA_HOME = "../images"
OUT_DIR = "../out"
RES_DIR = "../resources"
IMAGE_DIM = 224
# Out:
# Using TensorFlow backend.

# %%
# Load pretrained VGG-16
model = VGG16(weights='imagenet', include_top=True)
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
with open(join(RES_DIR, "imagenet_class_index.json")) as f:
    CLASS_INDICES = json.load(f)
        
def get_imagenet_label(indices, join=', '):
    return [CLASS_INDICES[str(idx)][1] for idx in indices]

# %%
# Say hello to our good friend
octocat = imread(join(DATA_HOME, "octocat.jpg"))
octocat = imresize(octocat, size=(IMAGE_DIM, IMAGE_DIM))
plt.imshow(octocat)
plt.axis("off")

# Get the first layer from VGG-16 and get the activations
model1 = Sequential()
model1.add(model.layers[0])
model1.add(model.layers[1])
model1.add(model.layers[2])
model1.add(Activation('relu'))

activations = model1.predict(np.asarray([octocat]))
fig, axis = plt.subplots(figsize=(16, 16), nrows=3, ncols=3)
for i, ax in enumerate(axis.flat):
    ax.set_title("Filter %s" % (i + 1))
    ax.imshow(activations[0, :, :, i], cmap="plasma")
    ax.axis("off")
fig.tight_layout()
plt.show()
fig.savefig(join(OUT_DIR,"convolutions.svg"), format="svg")

# %%
# Get images that maximise the activation in a certain layer
layer_name = 'predictions'
layer_idx = [idx for idx, layer in enumerate(model.layers) if layer.name == layer_name][0]

# Generate images for different classes
fig, axis = plt.subplots(figsize=(16, 12), nrows=3, ncols=4)
for i, ax in enumerate(axis.flat):
    index = i * 3
    image = visualize_activation(model, layer_idx, filter_indices=[index], text="", max_iter=500)
    ax.imshow(image)
    ax.set_title(get_imagenet_label([index])[0])
    ax.axis("off")
fig.tight_layout()
plt.show()
fig.savefig(join(OUT_DIR,"activations.svg"), format="svg")
# Out:
# Working on filters: [0]
# Working on filters: [3]
# Working on filters: [6]
# Working on filters: [9]
# Working on filters: [12]
# Working on filters: [15]
# Working on filters: [18]
# Working on filters: [21]
# Working on filters: [24]
# Working on filters: [27]
# Working on filters: [30]
# Working on filters: [33]

# %%
# Create gif of image for maximum activation during training
layer_name = 'predictions'
layer_dict = dict([(layer.name, layer) for layer in model.layers[1:]])
output_class = [283] # cats because reasons

losses = [
    (ActivationMaximization(layer_dict[layer_name], output_class), 2),
    (LPNorm(model.input), 10),
    (TotalVariation(model.input), 10)
]
opt = Optimizer(model.input, losses)
opt.minimize(max_iter=500, callbacks=[GifGenerator(join(OUT_DIR, 'cat_progress'))], verbose=False)
# Out:
# (array([[[255, 213, 227],
#          [255, 217, 225],
#          [255, 209, 221],
#          ...,
#          [209, 185, 183],
#          [214, 190, 188],
#          [215, 191, 191]],
#
#         [[255, 207, 217],
#          [255, 209, 221],
#          [255, 203, 212],
#          ...,
#          [209, 180, 180],
#          [213, 186, 187],
#          [217, 192, 192]],
#
#         [[250, 192, 205],
#          [252, 193, 204],
#          [251, 191, 201],
#          ...,
#          [204, 172, 173],
#          [208, 177, 178],
#          [211, 181, 182]],
#
#         ...,
#         [[251, 125, 154],
#          [252, 124, 154],
#          [248, 118, 150],
#          ...,
#          [255,  63, 255],
#          [255,  79, 255],
#          [255,  75, 255]],
#
#         [[255, 132, 163],
#          [255, 132, 164],
#          [255, 124, 159],
#          ...,
#          [255,  78, 255],
#          [255, 106, 255],
#          [255, 118, 255]],
#
#         [[255, 135, 165],
#          [255, 138, 170],
#          [255, 124, 160],
#          ...,
#          [255,  77, 255],
#          [255, 119, 255],
#          [255, 255, 255]]], dtype=uint8),
#  array([[[[-0.12041367, -0.10025727, -0.10720199],
#           [ 0.05129669,  0.12732427, -0.1249018 ],
#           [ 0.057177  , -0.08454456, -0.13697959],
#           ...,
#           [-0.20289963, -0.32715577,  0.15146945],
#           [-0.17007588, -0.51975816, -0.05346166],
#           [ 0.18838027,  0.1407049 ,  0.21496783]],
#
#          [[ 0.37003651,  0.2530154 ,  0.27285966],
#           [ 0.20469876,  0.43286979,  0.10500275],
#           [ 0.25436527,  0.32638356,  0.11432974],
#           ...,
#           [ 0.35942852, -0.49055052,  0.36840302],
#           [-0.60272992, -0.84507638, -0.51809454],
#           [ 0.20969391, -0.05996645,  0.28606948]],
#
#          [[-0.08906185,  0.09677956, -0.29718494],
#           [ 0.27598476, -0.18930869, -0.13297027],
#           [ 0.37109444,  0.3575618 , -0.17217371],
#           ...,
#           [-0.27809349, -1.06071544, -0.20816951],
#           [-0.47745392, -0.86149198, -0.32945722],
#           [ 0.16459171, -0.13780968,  0.21730725]],
#
#          ...,
#          [[ 0.45151713, -0.01828252, -0.10118043],
#           [-0.85138839, -0.23556463,  0.06068645],
#           [ 0.60182929,  0.40983132,  0.41588765],
#           ...,
#           [ 0.47253254,  0.16050366, -0.1070476 ],
#           [ 0.16361837,  0.51672971,  0.24766219],
#           [ 0.02196272,  0.05204906, -0.08352379]],
#
#          [[-0.48766819, -0.2411938 , -0.11938673],
#           [-0.19585514, -0.53988135, -0.44120145],
#           [-0.38488454, -0.22440851, -0.01041368],
#           ...,
#           [ 0.07314425,  0.46396729,  0.24397016],
#           [ 0.47497618,  0.70162719,  0.21811427],
#           [ 0.09044827,  0.23365711,  0.02499107]],
#
#          [[ 0.06148565, -0.0046987 ,  0.02456268],
#           [-0.20878044, -0.16557378, -0.09061909],
#           [-0.02929178, -0.06960148,  0.01745868],
#           ...,
#           [ 0.13021094,  0.15263253,  0.03627261],
#           [ 0.1201278 ,  0.29258111,  0.07503428],
#           [-0.36912134, -0.21083362, -0.38122702]]]], dtype=float32),
#  array([[[[ 212.76989746,  180.75982666,  188.43449402],
#           [ 213.04624939,  180.9559021 ,  188.86820984],
#           [ 210.60025024,  177.78312683,  184.99264526],
#           ...,
#           [ 179.23712158,  163.56442261,  164.51887512],
#           [ 181.56930542,  166.39543152,  167.5839386 ],
#           [ 181.80490112,  167.19726562,  168.72772217]],
#
#          [[ 207.49612427,  175.53305054,  183.11706543],
#           [ 209.24723816,  176.34519958,  184.42460632],
#           [ 206.85223389,  173.3717041 ,  180.55525208],
#           ...,
#           [ 176.67199707,  160.84934998,  161.90046692],
#           [ 180.50187683,  164.21174622,  166.40870667],
#           [ 182.25941467,  167.56158447,  168.8584137 ]],
#
#          [[ 201.38012695,  168.04399109,  177.1852417 ],
#           [ 202.28518677,  169.85514832,  177.20370483],
#           [ 200.71847534,  167.35028076,  174.32659912],
#           ...,
#           [ 175.10794067,  156.89910889,  158.86610413],
#           [ 177.18824768,  158.87731934,  161.4203186 ],
#           [ 178.14445496,  160.79466248,  162.93792725]],
#
#          ...,
#          [[ 200.34988403,  131.67776489,  147.44523621],
#           [ 202.60050964,  131.54644775,  146.96867371],
#           [ 198.77938843,  127.34634399,  144.55429077],
#           ...,
#           [ 364.50311279,   91.42405701,  215.18215942],
#           [ 377.82498169,   97.44833374,  224.51757812],
#           [ 380.88226318,   94.9998703 ,  225.76971436]],
#
#          [[ 208.1217041 ,  136.55122375,  152.7409668 ],
#           [ 208.60121155,  136.31439209,  153.60775757],
#           [ 205.79421997,  130.83059692,  149.917099  ],
#           ...,
#           [ 380.00457764,   97.35395813,  229.09495544],
#           [ 396.84231567,  111.526474  ,  244.16156006],
#           [ 406.34048462,  118.1373291 ,  252.50193787]],
#
#          [[ 209.12675476,  138.27156067,  154.37489319],
#           [ 213.42686462,  140.42881775,  157.40994263],
#           [ 207.21409607,  131.36297607,  150.73170471],
#           ...,
#           [ 384.25274658,   97.51529694,  233.40454102],
#           [ 405.31057739,  118.6124649 ,  252.55516052],
#           [ 467.44656372,  616.64666748,  258.1920166 ]]]], dtype=float32))

# %%
# Here we are going to make a grad-CAM heatmap. Such as described in https://arxiv.org/pdf/1610.02391v1.pdf

# We don't want a model with softmax here
bottom_model = VGG16(weights='imagenet', include_top=True, input_shape=(IMAGE_DIM, IMAGE_DIM, 3))
weights = bottom_model.layers[-1].get_weights()
bottom_model.layers.pop()
top = Dense(1000, activation="linear")(bottom_model.layers[-1].output)

model2 = Model(input=bottom_model.input, output=[top])
model2.layers[-1].set_weights(weights)

# Images to classify
image_paths = [
    join(DATA_HOME, "flamingo.jpg"),
    join(DATA_HOME, "tiger_cat.jpg"),
    join(DATA_HOME, "dumbbell.jpg"),
    join(DATA_HOME, "spider.jpg"),
    join(DATA_HOME, "birdhouse.jpg"),
    join(DATA_HOME, "chicken.jpg")
]

fig, axis = plt.subplots(figsize=(15, 10), nrows=2, ncols=3)
for i, ax in enumerate(axis.flat):
    seed_img = utils.load_img(image_paths[i], target_size=(224, 224))
    x = np.expand_dims(img_to_array(seed_img), axis=0)
    x = preprocess_input(x)
    pred_class = np.argmax(model2.predict(x))
    # Here we are asking it to show attention such that prob of `pred_class` is maximized.
    heatmap = visualize_cam(model2, len(model2.layers) -1, [pred_class], seed_img, alpha=0.6)
    ax.imshow(heatmap)
    ax.set_title(get_imagenet_label([pred_class])[0])
    ax.axis("off")

fig.tight_layout()
plt.show()
fig.savefig(join(OUT_DIR,"heatmap.svg"), format="svg")
# Out:
# /home/maxim/.virtualenvs/wad/lib/python3.6/site-packages/ipykernel_launcher.py:9: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=[<tf.Tenso...)`
#   if __name__ == '__main__':
# /home/maxim/.virtualenvs/wad/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Working on filters: [130]
# /home/maxim/.virtualenvs/wad/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Working on filters: [292]
# /home/maxim/.virtualenvs/wad/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Working on filters: [543]
# /home/maxim/.virtualenvs/wad/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Working on filters: [77]
# /home/maxim/.virtualenvs/wad/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Working on filters: [448]
# /home/maxim/.virtualenvs/wad/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Working on filters: [7]
